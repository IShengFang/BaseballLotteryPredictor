# %%
from bs4 import BeautifulSoup
import urllib
from urllib.request import urlopen
import pandas as pd
import os
import json
date = {'Jan': '01', 'Feb': '02', 'Mar': '03', 'Apr': '04', 'May': '05', 'Jun': '06',
        'Jul': '07', 'Aug': '08', 'Sep': '09', 'Oct': '10', 'Nov': '11', 'Dec': '12'}
week = ['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']

# %%
url = 'http://www.baseball-reference.com/previews/2014/ANA201404010.shtml'

# %%
data = pd.read_html(url)

# %%
x = data[0]
x.columns = range(x.shape[1])
x = x[x[0].notnull()]
x = x.loc[list(map(lambda x: len(x) > 15, x[0]))]
x = x.loc[:, 0]
x.index = range(x.shape[0])

# %%
data[0]
# Out:
#                                                   0    \
# 0                        Mariners, 1-0, 1-0 1st, ½ up
# 1                                               Split
# 2                                          2013 (5-3)
# 3                                          2012 (1-3)
# 4                                                 NaN
# 5                                           Last 7 GS
# 6                                          2013-09-29
# 7                                          2013-09-20
# 8                                          2013-09-15
# 9                                          2013-09-08
# 10                                         2013-09-03
# 11                                         2013-08-29
# 12                                         2013-08-24
# 13                                                NaN
# 14                                       Last 5 v.LAA
# 15                                         2013-09-20
# 16                                         2013-08-24
# 17                                         2012-09-25
# 18  Lineups / \tOrders / Splits: \tBat / \tPitch /...
# 19  Home: 0-0 Road: 1-0 ExtrInn: 0-0 vsRHP: 1-0 vs...
# 20             Angels, 0-1, 0-1 3rd, 1 GB, 1 GB in WC
# 21                                              Split
# 22                                        2013 (17-7)
# 23                                       2012 (13-10)
# 24                                        2011 (16-7)
# 25                                                NaN
# 26                                          Last 7 GS
# 27                                         2013-09-27
# 28                                         2013-09-22
# 29                                         2013-09-16
# 30                                         2013-09-11
# 31                                         2013-09-06
# 32                                         2013-09-01
# 33                                         2013-08-27
# 34                                                NaN
# 35                                       Last 5 v.SEA
# 36                                         2013-09-22
# 37                                         2013-06-19
# 38                                         2013-05-22
# 39                                         2013-04-26
# 40                                         2012-10-01
# 41  Lineups / \tOrders / Splits: \tBat / \tPitch /...
# 42  Home: 0-1 Road: 0-0 ExtrInn: 0-0 vsRHP: 0-1 vs...
# 43  Last 10 games for these teams head-to-head Mon...
#
#                                                   1      2      3    4    5    \
# 0   SP: Erasmo Ramirez (24, RHP, 0-0, undef) 2014 ...  Split    NaN  NaN   IP
# 1                                                 NaN    NaN     IP    H    R
# 2                                                 NaN    NaN   72.1   79   44
# 3                                                 NaN    NaN   59.0   47   26
# 4                                                 NaN    NaN    NaN  NaN  NaN
# 5                                                 NaN    1-3   36.0   40   19
# 6                                                 OAK      L    1.1    3    4
# 7                                                @LAA     ND    6.0    6    2
# 8                                                @STL      L    4.0    8    5
# 9                                                 TBR     ND    6.0    4    0
# 10                                               @KCR     ND    6.1    7    3
# 11                                               @HOU      W    5.2    5    2
# 12                                                LAA      L    6.2    7    3
# 13                                                NaN    NaN    NaN  NaN  NaN
# 14                                                NaN    0-2   18.2   20   10
# 15                                               @LAA     ND    6.0    6    2
# 16                                                LAA      L    6.2    7    3
# 17                                               @LAA      L    6.0    7    5
# 18                                                NaN    NaN    NaN  NaN  NaN
# 19                                                NaN    NaN    NaN  NaN  NaN
# 20  SP: C.J. Wilson (33, LHP, 0-0, undef) 2014 Gam...  Split    NaN  NaN   IP
# 21                                                NaN    NaN     IP    H    R
# 22                                                NaN    NaN  212.1  200   93
# 23                                                NaN    NaN  202.1  181  102
# 24                                                NaN    NaN  223.1  191   89
# 25                                                NaN    NaN    NaN  NaN  NaN
# 26                                                NaN    4-1   46.0   38   21
# 27                                               @TEX     ND    6.0    4    3
# 28                                                SEA      L    8.1    8    3
# 29                                               @OAK      W    7.0    4    1
# 30                                               @TOR      W    7.0    4    4
# 31                                                TEX      W    6.2    7    4
# 32                                               @MIL      W    6.0    3    3
# 33                                               @TBR     ND    5.0    8    3
# 34                                                NaN    NaN    NaN  NaN  NaN
# 35                                                NaN    4-1   35.0   29   10
# 36                                                SEA      L    8.1    8    3
# 37                                                SEA      W    7.0    2    0
# 38                                                SEA      W    8.0    6    1
# 39                                               @SEA      W    5.1    7    3
# 40                                               @SEA      W    6.1    6    3
# 41                                                NaN    NaN    NaN  NaN  NaN
# 42                                                NaN    NaN    NaN  NaN  NaN
# 43                                                NaN    NaN    NaN  NaN  NaN
#
#     6    7    8    9    ...   232  233  234  235  236  237  238  239    240  \
# 0     H    R   ER   BB  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 1    ER   BB   SO   HR  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 2    40   26   57   12  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 3    22   12   48    6  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 4   NaN  NaN  NaN  NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 5    16   16   27    5  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 6     4    4    3    0  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 7     0    1    3    0  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 8     5    0    1    1  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 9     0    4    5    0  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 10    3    3    3    2  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 11    2    2    7    1  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 12    2    2    5    1  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 13  NaN  NaN  NaN  NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 14    5    3   11    3  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 15    0    1    3    0  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 16    2    2    5    1  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 17    3    0    3    2  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 18  NaN  NaN  NaN  NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 19  NaN  NaN  NaN  NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 20    H    R   ER   BB  ...     W  6.1  6.0  3.0  2.0  5.0  7.0  1.0  107.0
# 21   ER   BB   SO   HR  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 22   80   85  188   15  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 23   86   91  173   19  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 24   73   74  206   16  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 25  NaN  NaN  NaN  NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 26   19   22   37    4  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 27    3    4    6    0  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 28    3    1    9    1  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 29    1    3    6    0  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 30    3    4    6    0  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 31    4    3    2    2  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 32    2    2    3    1  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 33    3    5    5    0  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 34  NaN  NaN  NaN  NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 35    9   12   38    2  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 36    3    1    9    1  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 37    0    2    3    0  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 38    1    2   10    0  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 39    3    2    9    0  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 40    2    5    7    1  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 41  NaN  NaN  NaN  NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 42  NaN  NaN  NaN  NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# 43  NaN  NaN  NaN  NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN
#
#      241
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20  53.0
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# 42   NaN
# 43   NaN
#
# [44 rows x 242 columns]

# %%
x[6]
# Out:
# 'Last 10 games for these teams head-to-head Mon, Mar 31, 2014 SEA 10 @LAA 3 W:Felix Hernandez (1-0), L: Jered Weaver (0-1), S: none Sun, Sep 22, 2013 SEA 3 @LAA 2 W:Oliver Perez (3-3), L: C.J. Wilson (17-7), S: Danny Farquhar (15) Sat, Sep 21, 2013 LAA 6 SEA 5 W:Jerome Williams (9-10), L: Joe Saunders (11-16), S: Ernesto Frieri (36) Fri, Sep 20, 2013 LAA 3 SEA 2 (11) W:Cory Rasmus (1-1), L: Bobby LaFromboise (0-1), S: none Sun, Aug 25, 2013 LAA 7 @SEA 1 W:Jered Weaver (8-7), L: Aaron Harang (5-11), S: none Sat, Aug 24, 2013 LAA 5 @SEA 1 W:Jason Vargas (7-5), L: Erasmo Ramirez (4-1), S: none Fri, Aug 23, 2013 LAA 2 @SEA 0 W:Garrett Richards (4-5), L: Felix Hernandez (12-7), S: Ernesto Frieri (27) Sun, Jul 14, 2013 SEA 4 LAA 3 W:Hisashi Iwakuma (8-4), L: Joe Blanton (2-12), S: Tom Wilhelmsen (19) Sat, Jul 13, 2013 SEA 6 LAA 0 W:Felix Hernandez (10-4), L: Jered Weaver (3-5), S: none Fri, Jul 12, 2013 SEA 8 LAA 3 W:Joe Saunders (8-8), L: Jerome Williams (5-5), S: none Season Series: 2014 - SEA over 1-0; 2013 - LAA won 11-8; 2012 - LAA won 11-8; All-Time - LAA leads 307-247'

# %%
data2 = pd.read_html('http://www.baseball-reference.com/previews/2014/ANA201407060.shtml')
data2[0]
# Out:
#                                                 Split  \
# 0   Date:Sunday, July 6, 2014Start Time:12:35pt (l...
# 1   Houston Astros36-53, 5th, 19 GB, 15½ GB in WC ...
# 2   Last 10 games for these teams head-to-head Sat...
# 3   SP: Collin McHugh (27, RHP, 4-7, 3.22) 2014 Ga...
# 4                                               Split
# 5                                          2014 (4-7)
# 6                                          2013 (0-4)
# 7                                          2012 (0-4)
# 8                                                 NaN
# 9                                           Last 7 GS
# 10                                         2014-06-30
# 11                                         2014-06-25
# 12                                         2014-06-19
# 13                                         2014-06-13
# 14                                         2014-06-08
# 15                                         2014-06-03
# 16                                         2014-05-27
# 17                                                NaN
# 18                                       Last 5 v.LAA
# 19                                         2014-06-03
# 20                                         2014-05-21
# 21                                              Split
# 22                                         2014 (9-2)
# 23                                         2013 (7-8)
# 24                                         2012 (4-3)
# 25                                                NaN
# 26                                          Last 7 GS
# 27                                         2014-07-01
# 28                                         2014-06-25
# 29                                         2014-06-20
# 30                                         2014-06-14
# 31                                         2014-06-09
# 32                                         2014-06-04
# 33                                         2014-05-30
# 34                                                NaN
# 35                                       Last 5 v.HOU
# 36                                         2014-06-04
# 37                                         2014-05-19
# 38                                         2014-04-04
# 39                                         2013-08-17
# 40                                         2013-04-13
#
#                                            Unnamed: 1 Unnamed: 2     IP    H  \
# 0                                                 NaN        NaN    NaN  NaN
# 1   Los Angeles Angels of Anaheim50-36, 2nd, 3½ GB...        NaN    NaN  NaN
# 2                                                 NaN        NaN    NaN  NaN
# 3                                               Split        NaN    NaN   IP
# 4                                                 NaN        NaN     IP    H
# 5                                                 NaN        NaN   78.1   54
# 6                                                 NaN        NaN   26.0   45
# 7                                                 NaN        NaN   21.1   27
# 8                                                 NaN        NaN    NaN  NaN
# 9                                                 NaN        2-4   40.1   27
# 10                                                SEA          L    6.0    5
# 11                                                ATL          L    7.0    3
# 12                                               @TBR          L    6.0    4
# 13                                                TBR          L    5.0    5
# 14                                               @MIN         ND    4.1    3
# 15                                                LAA          W    5.0    2
# 16                                               @KCR          W    7.0    5
# 17                                                NaN        NaN    NaN  NaN
# 18                                                NaN        1-1   12.0    6
# 19                                                LAA          W    5.0    2
# 20                                               @LAA          L    7.0    4
# 21                                                NaN        NaN     IP    H
# 22                                                NaN        NaN  109.0   77
# 23                                                NaN        NaN  145.0  151
# 24                                                NaN        NaN   71.0   77
# 25                                                NaN        NaN    NaN  NaN
# 26                                                NaN        5-1   43.0   27
# 27                                               @CHW          W    8.0    2
# 28                                                MIN          W    7.1    4
# 29                                                TEX          W    6.0    4
# 30                                               @ATL         ND    6.0    4
# 31                                                OAK          W    7.0    4
# 32                                               @HOU          W    8.0    4
# 33                                               @OAK          L    0.2    5
# 34                                                NaN        NaN    NaN  NaN
# 35                                                NaN        2-1   32.1   32
# 36                                               @HOU          W    8.0    4
# 37                                                HOU          L    7.0   10
# 38                                               @HOU          W    5.0    3
# 39                                                HOU         ND    6.0   12
# 40                                                HOU         ND    6.1    3
#
#       R   ER   BB   SO   HR      ...      Unnamed: 436 Unnamed: 437  \
# 0   NaN  NaN  NaN  NaN  NaN      ...               NaN          NaN
# 1   NaN  NaN  NaN  NaN  NaN      ...               NaN          NaN
# 2   NaN  NaN  NaN  NaN  NaN      ...               NaN          NaN
# 3     H    R   ER   BB   SO      ...                ND          6.1
# 4     R   ER   BB   SO   HR      ...               NaN          NaN
# 5    32   28   31   89    8      ...               NaN          NaN
# 6    29   29    5   11    6      ...               NaN          NaN
# 7    21   18    8   17    5      ...               NaN          NaN
# 8   NaN  NaN  NaN  NaN  NaN      ...               NaN          NaN
# 9    17   14   19   48    5      ...               NaN          NaN
# 10    5    5    4    8    3      ...               NaN          NaN
# 11    3    3    2    9    1      ...               NaN          NaN
# 12    2    0    3    6    0      ...               NaN          NaN
# 13    4    3    3    6    0      ...               NaN          NaN
# 14    3    3    5    6    1      ...               NaN          NaN
# 15    0    0    2    4    0      ...               NaN          NaN
# 16    0    0    0    9    0      ...               NaN          NaN
# 17  NaN  NaN  NaN  NaN  NaN      ...               NaN          NaN
# 18    2    2    4   11    1      ...               NaN          NaN
# 19    0    0    2    4    0      ...               NaN          NaN
# 20    2    2    2    7    1      ...               NaN          NaN
# 21    R   ER   BB   SO   HR      ...               NaN          NaN
# 22   34   34   40  108    4      ...               NaN          NaN
# 23   73   67   44  101   12      ...               NaN          NaN
# 24   46   37   34   47    7      ...               NaN          NaN
# 25  NaN  NaN  NaN  NaN  NaN      ...               NaN          NaN
# 26   12   12   16   46    3      ...               NaN          NaN
# 27    3    3    2    9    1      ...               NaN          NaN
# 28    2    2    5    5    1      ...               NaN          NaN
# 29    1    1    3    7    0      ...               NaN          NaN
# 30    0    0    3   10    0      ...               NaN          NaN
# 31    1    1    0    4    0      ...               NaN          NaN
# 32    0    0    0    9    0      ...               NaN          NaN
# 33    5    5    3    2    1      ...               NaN          NaN
# 34  NaN  NaN  NaN  NaN  NaN      ...               NaN          NaN
# 35   15   15   10   25    2      ...               NaN          NaN
# 36    0    0    0    9    0      ...               NaN          NaN
# 37    5    5    2    1    0      ...               NaN          NaN
# 38    1    1    5    7    0      ...               NaN          NaN
# 39    5    5    0    7    1      ...               NaN          NaN
# 40    4    4    3    1    1      ...               NaN          NaN
#
#    Unnamed: 438 Unnamed: 439  Unnamed: 440  Unnamed: 441  Unnamed: 442  \
# 0           NaN          NaN           NaN           NaN           NaN
# 1           NaN          NaN           NaN           NaN           NaN
# 2           NaN          NaN           NaN           NaN           NaN
# 3           3.0          4.0           4.0           3.0           1.0
# 4           NaN          NaN           NaN           NaN           NaN
# 5           NaN          NaN           NaN           NaN           NaN
# 6           NaN          NaN           NaN           NaN           NaN
# 7           NaN          NaN           NaN           NaN           NaN
# 8           NaN          NaN           NaN           NaN           NaN
# 9           NaN          NaN           NaN           NaN           NaN
# 10          NaN          NaN           NaN           NaN           NaN
# 11          NaN          NaN           NaN           NaN           NaN
# 12          NaN          NaN           NaN           NaN           NaN
# 13          NaN          NaN           NaN           NaN           NaN
# 14          NaN          NaN           NaN           NaN           NaN
# 15          NaN          NaN           NaN           NaN           NaN
# 16          NaN          NaN           NaN           NaN           NaN
# 17          NaN          NaN           NaN           NaN           NaN
# 18          NaN          NaN           NaN           NaN           NaN
# 19          NaN          NaN           NaN           NaN           NaN
# 20          NaN          NaN           NaN           NaN           NaN
# 21          NaN          NaN           NaN           NaN           NaN
# 22          NaN          NaN           NaN           NaN           NaN
# 23          NaN          NaN           NaN           NaN           NaN
# 24          NaN          NaN           NaN           NaN           NaN
# 25          NaN          NaN           NaN           NaN           NaN
# 26          NaN          NaN           NaN           NaN           NaN
# 27          NaN          NaN           NaN           NaN           NaN
# 28          NaN          NaN           NaN           NaN           NaN
# 29          NaN          NaN           NaN           NaN           NaN
# 30          NaN          NaN           NaN           NaN           NaN
# 31          NaN          NaN           NaN           NaN           NaN
# 32          NaN          NaN           NaN           NaN           NaN
# 33          NaN          NaN           NaN           NaN           NaN
# 34          NaN          NaN           NaN           NaN           NaN
# 35          NaN          NaN           NaN           NaN           NaN
# 36          NaN          NaN           NaN           NaN           NaN
# 37          NaN          NaN           NaN           NaN           NaN
# 38          NaN          NaN           NaN           NaN           NaN
# 39          NaN          NaN           NaN           NaN           NaN
# 40          NaN          NaN           NaN           NaN           NaN
#
#     Unnamed: 443  Unnamed: 444  Unnamed: 445
# 0            NaN           NaN           NaN
# 1            NaN           NaN           NaN
# 2            NaN           NaN           NaN
# 3            1.0          86.0          49.0
# 4            NaN           NaN           NaN
# 5            NaN           NaN           NaN
# 6            NaN           NaN           NaN
# 7            NaN           NaN           NaN
# 8            NaN           NaN           NaN
# 9            NaN           NaN           NaN
# 10           NaN           NaN           NaN
# 11           NaN           NaN           NaN
# 12           NaN           NaN           NaN
# 13           NaN           NaN           NaN
# 14           NaN           NaN           NaN
# 15           NaN           NaN           NaN
# 16           NaN           NaN           NaN
# 17           NaN           NaN           NaN
# 18           NaN           NaN           NaN
# 19           NaN           NaN           NaN
# 20           NaN           NaN           NaN
# 21           NaN           NaN           NaN
# 22           NaN           NaN           NaN
# 23           NaN           NaN           NaN
# 24           NaN           NaN           NaN
# 25           NaN           NaN           NaN
# 26           NaN           NaN           NaN
# 27           NaN           NaN           NaN
# 28           NaN           NaN           NaN
# 29           NaN           NaN           NaN
# 30           NaN           NaN           NaN
# 31           NaN           NaN           NaN
# 32           NaN           NaN           NaN
# 33           NaN           NaN           NaN
# 34           NaN           NaN           NaN
# 35           NaN           NaN           NaN
# 36           NaN           NaN           NaN
# 37           NaN           NaN           NaN
# 38           NaN           NaN           NaN
# 39           NaN           NaN           NaN
# 40           NaN           NaN           NaN
#
# [41 rows x 446 columns]

# %%
## road
texts = x[2]
texts = texts.replace('(', ' (')
texts = texts.replace(':', ' ')

# team name
team_name = ""
for text in x[0]:
    if text == ',':
        break
    team_name += text

# data detail
texts_split = texts.split(" ")
while "" in texts_split:
    texts_split.remove("")
texts_detail = texts_split[texts_split.index("Home"):texts_split.index("IL")+2]
road = dict({"Team name": team_name})
for index in range(0, len(texts_detail), 2):
    road[texts_detail[index]] = texts_detail[index+1]

# last 10 games
last_10_games = texts_split.copy()
last_10_games.remove('Last')
last_10_games = last_10_games[last_10_games.index('Place/GB')+1:last_10_games.index('Last')]
while "" in last_10_games:
    last_10_games.remove("")
for item in last_10_games:
    if "(" in item:
        last_10_games.remove(item)
while 'gb' in last_10_games:
    last_10_games.remove('gb')
while 'up' in last_10_games:
    last_10_games.remove('up')
while '-' in last_10_games:
    if last_10_games.index('-')%10 == 5:
        last_10_games[last_10_games.index('-')] = 'T'
    else:
        fore = last_10_games[:last_10_games.index('-')]
        back = last_10_games[last_10_games.index('-')+1:]
        last_10_games = fore + [None, None, None] + back
last_10_game_list = []
for i in range(0, 100, 10):
    if i > len(last_10_games)-1:
        last_10_game_list.append([None, None, None, None, None, None, None, None])
    else:
        if len(last_10_games[i+3]) < 2:
            day = date[last_10_games[i+2]] + '0' + last_10_games[i+3]
        else:
            day = date[last_10_games[i+2]] + last_10_games[i+3]
        if '@' in last_10_games[i+4]:
            opp = last_10_games[i+4]
            opp = opp.replace("@", "")
            flag = 0
        else:
            opp = last_10_games[i+4]
            flag = 1
        if last_10_games[i+5] == 'W':
            W_L = 1
        elif last_10_games[i+5] == 'L':
            W_L = 0
        else:
            W_L = 0.5
        if len(last_10_games[i+3]) == 1:
            last_10_games[i+3] = '0' + last_10_games[i+3]
        if last_10_games[i+7] != None:
            record = last_10_games[i+7]
        else:
            record = None
        if last_10_games[i+8] != None:
            place = int(last_10_games[i+8][0])
        else:
            place = None
        if last_10_games[i+9] != None:
            try:
                GB = float(last_10_games[i+9])
            except:
                GB = 0.0
        else:
            GB = None
        last_10_game_list.append([day,
                                  flag,
                                  opp,
                                  W_L,
                                  last_10_games[i+6],
                                  record,
                                  place,
                                  GB])
road["last_10_game"] = last_10_game_list


## home
texts = x[5]
texts = texts.replace('(', ' (')
texts = texts.replace(':', ' ')

# team name
team_name = ""
for text in x[3]:
    if text == ',':
        break
    team_name += text

# data detail
texts_split = texts.split(" ")
while "" in texts_split:
    texts_split.remove("")
texts_detail = texts_split[texts_split.index("Home"):texts_split.index("IL")+2]
home = dict({"Team name": team_name})
for index in range(0, len(texts_detail), 2):
    home[texts_detail[index]] = texts_detail[index+1]

# last 10 games
last_10_games = texts_split.copy()
last_10_games.remove('Last')
last_10_games = last_10_games[last_10_games.index('Place/GB')+1:last_10_games.index('Last')]
while "" in last_10_games:
    last_10_games.remove("")
for item in last_10_games:
    if "(" in item:
        last_10_games.remove(item)
while 'gb' in last_10_games:
    last_10_games.remove('gb')
while 'up' in last_10_games:
    last_10_games.remove('up')
while '-' in last_10_games:
    if last_10_games.index('-')%10 == 5:
        last_10_games[last_10_games.index('-')] = 'T'
    else:
        fore = last_10_games[:last_10_games.index('-')]
        back = last_10_games[last_10_games.index('-')+1:]
        last_10_games = fore + [None, None, None] + back
last_10_game_list = []
for i in range(0, 100, 10):
    if i > len(last_10_games)-1:
        last_10_game_list.append([None, None, None, None, None, None, None, None])
    else:
        if len(last_10_games[i+3]) < 2:
            day = date[last_10_games[i+2]] + '0' + last_10_games[i+3]
        else:
            day = date[last_10_games[i+2]] + last_10_games[i+3]
        if '@' in last_10_games[i+4]:
            opp = last_10_games[i+4]
            opp = opp.replace("@", "")
            flag = 0
        else:
            opp = last_10_games[i+4]
            flag = 1
        if last_10_games[i+5] == 'W':
            W_L = 1
        elif last_10_games[i+5] == 'L':
            W_L = 0
        else:
            W_L = 0.5
        if len(last_10_games[i+3]) == 1:
            last_10_games[i+3] = '0' + last_10_games[i+3]
        if last_10_games[i+7] != None:
            record = last_10_games[i+7]
        else:
            record = None
        if last_10_games[i+8] != None:
            place = int(last_10_games[i+8][0])
        else:
            place = None
        if last_10_games[i+9] != None:
            try:
                GB = float(last_10_games[i+9])
            except:
                GB = 0.0
        else:
            GB = None
        last_10_game_list.append([day,
                                  flag,
                                  opp,
                                  W_L,
                                  last_10_games[i+6],
                                  record,
                                  place,
                                  GB])
home["last_10_game"] = last_10_game_list

## head_to_head
try:
    texts = x[6]
    texts = texts.replace('(', ' (')
    texts = texts.replace(",", "")
    texts_split = texts.split(" ")
    head_to_head = texts_split.copy()
    while "" in head_to_head:
        head_to_head.remove("")
    for item in head_to_head:
        if "(" in item:
            head_to_head.remove(item)

    head_to_head = head_to_head[head_to_head.index('head-to-head')+1:head_to_head.index('Season')]
    new_head = []
    i = 0
    while i < len(head_to_head):
        if head_to_head[i] in week:
            j = i+1
            while not 'W:' in head_to_head[j]:
                j += 1
            new_head.append(head_to_head[i+1:j])
            i = j+1
        else:
            i += 1
    head_to_head = []
    for i in range(10):
        try:
            day = new_head[i][2] + date[new_head[i][0]] + new_head[i][1]
            if '@' in new_head[i][5]:
                flag = 0
                loss = new_head[i][5].replace('@', '')
            else:
                flag = 1
                loss = new_head[i][5]
            win = new_head[i][3]
            l = [day, win, loss, flag, int(new_head[i][4]), int(new_head[i][6])]
        except:
            l = [None, None, None, None, None, None]

        head_to_head.append(l)
except:
    head_to_head = []
    for i in range(10):
        head_to_head.append([None, None, None, None, None, None])

# %%
road
# Out:
# {'1-Run': '0-0',
#  'ExtrInn': '0-0',
#  'Home': '0-0',
#  'IL': '0-0',
#  'Road': '1-0',
#  'Team name': 'Mariners',
#  'last_10_game': [['0331', 0, 'LAA', 1, '10-3', '1-0', 1, 0.5],
#   [None, None, None, None, None, None, None, None],
#   [None, None, None, None, None, None, None, None],
#   [None, None, None, None, None, None, None, None],
#   [None, None, None, None, None, None, None, None],
#   [None, None, None, None, None, None, None, None],
#   [None, None, None, None, None, None, None, None],
#   [None, None, None, None, None, None, None, None],
#   [None, None, None, None, None, None, None, None],
#   [None, None, None, None, None, None, None, None]],
#  'vsCntrl': '0-0',
#  'vsEast': '0-0',
#  'vsLHP': '0-0',
#  'vsRHP': '1-0',
#  'vsWest': '1-0'}

# %%
home
# Out:
# {'1-Run': '0-0',
#  'ExtrInn': '0-0',
#  'Home': '0-1',
#  'IL': '0-0',
#  'Road': '0-0',
#  'Team name': 'Angels',
#  'last_10_game': [['0331', 1, 'SEA', 0, '3-10', '0-1', 3, 1.0],
#   [None, None, None, None, None, None, None, None],
#   [None, None, None, None, None, None, None, None],
#   [None, None, None, None, None, None, None, None],
#   [None, None, None, None, None, None, None, None],
#   [None, None, None, None, None, None, None, None],
#   [None, None, None, None, None, None, None, None],
#   [None, None, None, None, None, None, None, None],
#   [None, None, None, None, None, None, None, None],
#   [None, None, None, None, None, None, None, None]],
#  'vsCntrl': '0-0',
#  'vsEast': '0-0',
#  'vsLHP': '0-0',
#  'vsRHP': '0-1',
#  'vsWest': '0-1'}

# %%
head_to_head
# Out:
# [['20140331', 'SEA', 'LAA', 0, 10, 3],
#  ['20130922', 'SEA', 'LAA', 0, 3, 2],
#  ['20130921', 'LAA', 'SEA', 1, 6, 5],
#  ['20130920', 'LAA', 'SEA', 1, 3, 2],
#  ['20130825', 'LAA', 'SEA', 0, 7, 1],
#  ['20130824', 'LAA', 'SEA', 0, 5, 1],
#  ['20130823', 'LAA', 'SEA', 0, 2, 0],
#  ['20130714', 'SEA', 'LAA', 1, 4, 3],
#  ['20130713', 'SEA', 'LAA', 1, 6, 0],
#  ['20130712', 'SEA', 'LAA', 1, 8, 3]]

# %%
new_head
# Out:
# [['Mar', '31', '2014', 'SEA', '10', '@LAA', '3'],
#  ['Sep', '22', '2013', 'SEA', '3', '@LAA', '2'],
#  ['Sep', '21', '2013', 'LAA', '6', 'SEA', '5'],
#  ['Sep', '20', '2013', 'LAA', '3', 'SEA', '2'],
#  ['Aug', '25', '2013', 'LAA', '7', '@SEA', '1'],
#  ['Aug', '24', '2013', 'LAA', '5', '@SEA', '1'],
#  ['Aug', '23', '2013', 'LAA', '2', '@SEA', '0'],
#  ['Jul', '14', '2013', 'SEA', '4', 'LAA', '3'],
#  ['Jul', '13', '2013', 'SEA', '6', 'LAA', '0'],
#  ['Jul', '12', '2013', 'SEA', '8', 'LAA', '3']]
